# %%
# !pip install tf-nightly-2.0-preview
# Out:
# Requirement already satisfied: tf-nightly-2.0-preview in /usr/local/lib/python3.6/dist-packages (2.0.0.dev20191002)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (0.8.0)
# Requirement already satisfied: tensorflow-estimator-2.0-preview in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (2.0.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.12.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (3.7.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (3.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.16.5)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.1.0)
# Requirement already satisfied: tb-nightly<2.2.0a0,>=2.1.0a0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (2.1.0a20191016)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.11.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.15.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (0.33.6)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (0.2.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (0.1.7)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (0.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tf-nightly-2.0-preview) (41.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tf-nightly-2.0-preview) (2.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.2.0a0,>=2.1.0a0->tf-nightly-2.0-preview) (0.16.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.2.0a0,>=2.1.0a0->tf-nightly-2.0-preview) (3.1.1)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.0.0-dev20191002

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(False)

def trend(time, slope=0):
    return slope * time

def seasonal_pattern(season_time):
    """Just an arbitrary pattern, you can change it if you wish"""
    return np.where(season_time < 0.1,
                    np.cos(season_time * 6 * np.pi) # YOUR CODE HERE # * np.pi),
                    , 2 / np.exp(9 * season_time))#YOUR CODE HERE# / np.exp(#YOUR CODE HERE# * season_time))

def seasonality(time, period, amplitude=1, phase=0):
    """Repeats the same pattern at each period"""
    season_time = ((time + phase) % period) / period
    return amplitude * seasonal_pattern(season_time)

def noise(time, noise_level=1, seed=None):
    rnd = np.random.RandomState(seed)
    return rnd.randn(len(time)) * noise_level

time = np.arange(10 * 365 + 1, dtype="float32")
baseline = 10# YOUR CODE HERE #
series = trend(time, 0.1) # YOUR CODE HERE#)  
baseline = 10
amplitude = 40
slope = 0.005# YOUR CODE HERE#
noise_level = 3 # YOUR CODE HERE#

# Create the series
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)
# Update with noise
series += noise(time, noise_level, seed=51)

split_time = 3000
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

window_size = 20
batch_size = 32
shuffle_buffer_size = 1000

plot_series(time, series)

# %% [markdown]
# Desired output -- a chart that looks like this:
#
# ![Chart showing upward trend and seasonailty](http://www.laurencemoroney.com/wp-content/uploads/2019/07/plot1.png)

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
  dataset = tf.data.Dataset.from_tensor_slices(series)
  dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
  dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
  dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1]))
  dataset = dataset.batch(batch_size).prefetch(1)
  return dataset

# %%
dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)


model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(100, input_shape = [window_size], activation = 'relu'),# YOUR CODE HERE #),
    tf.keras.layers.Dense(20, activation = 'relu'), # YOUR CODE HERE #, activation="relu"), 
    tf.keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer = tf.keras.optimizers.SGD(lr = 1e-6, momentum=0.9))# YOUR CODE HERE #, optimizer=# YOUR CODE HERE#))
history = model.fit(dataset,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 1s 11ms/step - loss: 61.8064
# Epoch 2/100
# 94/94 [==============================] - 0s 4ms/step - loss: 42.4846
# Epoch 3/100
# 94/94 [==============================] - 0s 4ms/step - loss: 36.1290
# Epoch 4/100
# 94/94 [==============================] - 0s 4ms/step - loss: 32.1917
# Epoch 5/100
# 94/94 [==============================] - 0s 4ms/step - loss: 32.4365
# Epoch 6/100
# 94/94 [==============================] - 0s 4ms/step - loss: 29.1845
# Epoch 7/100
# 94/94 [==============================] - 0s 4ms/step - loss: 27.8285
# Epoch 8/100
# 94/94 [==============================] - 0s 5ms/step - loss: 27.0647
# Epoch 9/100
# 94/94 [==============================] - 0s 5ms/step - loss: 26.3752
# Epoch 10/100
# 94/94 [==============================] - 0s 4ms/step - loss: 26.1442
# Epoch 11/100
# 94/94 [==============================] - 0s 5ms/step - loss: 25.7869
# Epoch 12/100
# 94/94 [==============================] - 0s 4ms/step - loss: 25.7625
# Epoch 13/100
# 94/94 [==============================] - 0s 4ms/step - loss: 25.6003
# Epoch 14/100
# 94/94 [==============================] - 0s 5ms/step - loss: 24.7767
# Epoch 15/100
# 94/94 [==============================] - 0s 4ms/step - loss: 24.4102
# Epoch 16/100
# 94/94 [==============================] - 0s 4ms/step - loss: 24.6031
# Epoch 17/100
# 94/94 [==============================] - 0s 4ms/step - loss: 24.2588
# Epoch 18/100
# 94/94 [==============================] - 0s 4ms/step - loss: 24.1711
# Epoch 19/100
# 94/94 [==============================] - 0s 4ms/step - loss: 23.8895
# Epoch 20/100
# 94/94 [==============================] - 0s 4ms/step - loss: 23.7422
# Epoch 21/100
# 94/94 [==============================] - 0s 4ms/step - loss: 23.6199
# Epoch 22/100
# 94/94 [==============================] - 0s 4ms/step - loss: 23.3503
# Epoch 23/100
# 94/94 [==============================] - 0s 5ms/step - loss: 23.3887
# Epoch 24/100
# 94/94 [==============================] - 0s 4ms/step - loss: 23.1183
# Epoch 25/100
# 94/94 [==============================] - 0s 4ms/step - loss: 23.1125
# Epoch 26/100
# 94/94 [==============================] - 0s 5ms/step - loss: 22.9987
# Epoch 27/100
# 94/94 [==============================] - 0s 4ms/step - loss: 22.9254
# Epoch 28/100
# 94/94 [==============================] - 0s 4ms/step - loss: 22.9365
# Epoch 29/100
# 94/94 [==============================] - 0s 5ms/step - loss: 25.8639
# Epoch 30/100
# 94/94 [==============================] - 0s 5ms/step - loss: 22.9093
# Epoch 31/100
# 94/94 [==============================] - 0s 4ms/step - loss: 22.8700
# Epoch 32/100
# 94/94 [==============================] - 0s 4ms/step - loss: 22.6375
# Epoch 33/100
# 94/94 [==============================] - 0s 4ms/step - loss: 22.5231
# Epoch 34/100
# 94/94 [==============================] - 0s 4ms/step - loss: 22.4935
# Epoch 35/100
# 94/94 [==============================] - 0s 4ms/step - loss: 22.2759
# Epoch 36/100
# 94/94 [==============================] - 0s 5ms/step - loss: 22.3326
# Epoch 37/100
# 94/94 [==============================] - 0s 4ms/step - loss: 22.0690
# Epoch 38/100
# 94/94 [==============================] - 0s 4ms/step - loss: 22.1505
# Epoch 39/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.8872
# Epoch 40/100
# 94/94 [==============================] - 0s 5ms/step - loss: 21.9088
# Epoch 41/100
# 94/94 [==============================] - 0s 4ms/step - loss: 25.0635
# Epoch 42/100
# 94/94 [==============================] - 0s 4ms/step - loss: 22.0655
# Epoch 43/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.8296
# Epoch 44/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.9351
# Epoch 45/100
# 94/94 [==============================] - 0s 5ms/step - loss: 21.7413
# Epoch 46/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.7401
# Epoch 47/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.7245
# Epoch 48/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.6939
# Epoch 49/100
# 94/94 [==============================] - 0s 5ms/step - loss: 21.6114
# Epoch 50/100
# 94/94 [==============================] - 0s 5ms/step - loss: 21.6706
# Epoch 51/100
# 94/94 [==============================] - 0s 5ms/step - loss: 24.6874
# Epoch 52/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.5262
# Epoch 53/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.3672
# Epoch 54/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.4365
# Epoch 55/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.3627
# Epoch 56/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.3497
# Epoch 57/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.3193
# Epoch 58/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.2717
# Epoch 59/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.2684
# Epoch 60/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.1874
# Epoch 61/100
# 94/94 [==============================] - 0s 4ms/step - loss: 24.4560
# Epoch 62/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.2745
# Epoch 63/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.2249
# Epoch 64/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.0750
# Epoch 65/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.2220
# Epoch 66/100
# 94/94 [==============================] - 0s 5ms/step - loss: 20.9882
# Epoch 67/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.6253
# Epoch 68/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.1023
# Epoch 69/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.1386
# Epoch 70/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.9127
# Epoch 71/100
# 94/94 [==============================] - 0s 4ms/step - loss: 21.3571
# Epoch 72/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.8941
# Epoch 73/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.9379
# Epoch 74/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.9210
# Epoch 75/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.7558
# Epoch 76/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.8967
# Epoch 77/100
# 94/94 [==============================] - 0s 5ms/step - loss: 20.8100
# Epoch 78/100
# 94/94 [==============================] - 0s 5ms/step - loss: 20.9538
# Epoch 79/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.7968
# Epoch 80/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.9071
# Epoch 81/100
# 94/94 [==============================] - 0s 5ms/step - loss: 20.7572
# Epoch 82/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.8317
# Epoch 83/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.8099
# Epoch 84/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.6799
# Epoch 85/100
# 94/94 [==============================] - 0s 5ms/step - loss: 20.7901
# Epoch 86/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.7737
# Epoch 87/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.6861
# Epoch 88/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.6095
# Epoch 89/100
# 94/94 [==============================] - 0s 5ms/step - loss: 20.5628
# Epoch 90/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.6313
# Epoch 91/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.5509
# Epoch 92/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.5556
# Epoch 93/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.5467
# Epoch 94/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.5279
# Epoch 95/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.4211
# Epoch 96/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.5754
# Epoch 97/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.5259
# Epoch 98/100
# 94/94 [==============================] - 0s 5ms/step - loss: 20.6843
# Epoch 99/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.4584
# Epoch 100/100
# 94/94 [==============================] - 0s 4ms/step - loss: 20.4811

# %%
forecast = []
for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]


plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# EXPECTED OUTPUT
# A Value less than 3
# Out:
# 2.9244413

# %%
# Self add 
loss = history.history['loss']
epochs = range(len(loss))
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.show()
